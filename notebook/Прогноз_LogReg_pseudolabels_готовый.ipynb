# %% [markdown]
# # Прогноз золото-урановых зон: Logistic Regression + pseudo-labels
#
# Финальная версия ноутбука: **ML-основа через Logistic Regression**.
#
# Модель обучается на:
# 1. реальных точках проявлений / аномалий;
# 2. псевдометках, полученных из наиболее уверенных зон `geo_score`.
#
# Random Forest полностью убран. Итог сохраняется **только в PNG**.

# %%
# Установка библиотек при необходимости:
# !pip install geopandas shapely pyogrio fiona scikit-learn scipy matplotlib pandas numpy

import os
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

from shapely.geometry import box
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, average_precision_score

try:
    from scipy.ndimage import gaussian_filter
    HAS_SCIPY = True
except Exception:
    HAS_SCIPY = False

pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## 1. Настройки
#
# Проверь пути под свою папку проекта.
# Обычно структура такая:
#
# ```text
# Прогноз/
#     shp_dbf/
#     ml_forecast_result/
# ```

# %%
# ===== ПУТИ =====
BASE_DIR = Path(r"C:\Users\janfi\OneDrive\Desktop\Прочее\Прогноз")

# Если ноутбук запускается рядом с папкой shp_dbf, можно использовать:
# BASE_DIR = Path.cwd()

SHP_DIR = BASE_DIR / "shp_dbf"
OUT_DIR = BASE_DIR / "ml_forecast_result"
OUT_DIR.mkdir(parents=True, exist_ok=True)

# ===== ПАРАМЕТРЫ СЕТКИ =====
CELL_SIZE = 500  # метров

# ===== PSEUDO-LABELS =====
PSEUDO_POS_Q = 0.94
PSEUDO_NEG_Q = 0.50

# ===== МОДЕЛЬ =====
RANDOM_STATE = 42
LOGREG_C = 1.0
MAX_ITER = 3000

# ===== ПОСТОБРАБОТКА =====
GEO_STABILIZER = 0.15
SMOOTH_SIGMA = 1.25
FINAL_ZONE_Q = 0.90

# ===== ВЫВОД =====
PNG_PATH = OUT_DIR / "logreg_pseudolabels_forecast.png"

print("BASE_DIR:", BASE_DIR)
print("SHP_DIR:", SHP_DIR)
print("OUT_DIR:", OUT_DIR)
# Out:
# BASE_DIR: C:\Users\janfi\OneDrive\Desktop\Прочее\Прогноз
# SHP_DIR: C:\Users\janfi\OneDrive\Desktop\Прочее\Прогноз\shp_dbf
# OUT_DIR: C:\Users\janfi\OneDrive\Desktop\Прочее\Прогноз\ml_forecast_result

# %% [markdown]
# ## 2. Служебные функции

# %%
def read_vector(path: Path) -> gpd.GeoDataFrame:
    """Чтение векторного слоя."""
    gdf = gpd.read_file(path)
    gdf = gdf[~gdf.geometry.isna()].copy()
    if len(gdf) > 0:
        try:
            gdf["geometry"] = gdf.geometry.buffer(0)
        except Exception:
            pass
        gdf = gdf[~gdf.geometry.is_empty].copy()
    return gdf


def robust_normalize_01(values, q_low=0.02, q_high=0.98, invert=False):
    """Робастная нормализация в диапазон 0..1."""
    s = pd.Series(values).astype(float)
    lo = s.quantile(q_low)
    hi = s.quantile(q_high)
    if hi == lo:
        out = np.zeros(len(s), dtype=float)
    else:
        out = ((s - lo) / (hi - lo)).clip(0, 1).to_numpy()
    if invert:
        out = 1 - out
    return out


def find_layer_by_keywords(layers, keywords):
    """Поиск слоя по ключевым словам."""
    keys = [k.lower() for k in keywords]
    for name in layers:
        low = name.lower()
        if any(k in low for k in keys):
            return name
    return None


def make_grid(mask_gdf, cell_size=500):
    """Создание регулярной сетки по границам маски."""
    xmin, ymin, xmax, ymax = mask_gdf.total_bounds
    xs = np.arange(xmin, xmax + cell_size, cell_size)
    ys = np.arange(ymin, ymax + cell_size, cell_size)

    geoms = []
    for x in xs[:-1]:
        for y in ys[:-1]:
            geoms.append(box(x, y, x + cell_size, y + cell_size))

    grid = gpd.GeoDataFrame({"geometry": geoms}, crs=mask_gdf.crs)
    mask_union = mask_gdf.geometry.unary_union
    grid = grid[grid.intersects(mask_union)].copy()
    grid["geometry"] = grid.geometry.intersection(mask_union)
    grid = grid[~grid.geometry.is_empty].copy()
    grid["cell_id"] = np.arange(len(grid))
    grid["centroid"] = grid.geometry.centroid
    return grid


def distance_to_layer(grid, layer_gdf):
    """Расстояние от центроидов ячеек до ближайшего объекта слоя."""
    if layer_gdf is None or len(layer_gdf) == 0:
        return np.full(len(grid), np.nan)
    union = layer_gdf.geometry.unary_union
    return grid["centroid"].distance(union).to_numpy()


def add_distance_feature(grid, layer_gdf, raw_name, score_name):
    """Добавить расстояние и score близости: ближе = лучше."""
    dist = distance_to_layer(grid, layer_gdf)
    grid[raw_name] = dist
    grid[score_name] = robust_normalize_01(dist, invert=True)
    return grid


def collect_point_layers(all_layers, factor_layer_names, target_crs):
    """Собрать точечные слои, которые не являются факторными."""
    point_parts = []
    factor_set = set([x for x in factor_layer_names if x is not None])

    for name, gdf in all_layers.items():
        if name in factor_set:
            continue
        if len(gdf) == 0:
            continue

        geom_types = set(gdf.geometry.geom_type.unique())
        if geom_types.intersection({"Point", "MultiPoint"}):
            pts = gdf.copy()
            if pts.crs != target_crs:
                pts = pts.to_crs(target_crs)
            pts["source"] = name
            point_parts.append(pts[["source", "geometry"]])

    if not point_parts:
        return None

    points = pd.concat(point_parts, ignore_index=True)
    points = gpd.GeoDataFrame(points, geometry="geometry", crs=target_crs)
    points = points.explode(index_parts=False).reset_index(drop=True)
    return points


def smooth_grid_values(grid, value_col, out_col, sigma=1.25):
    """Сглаживание значений на регулярной сетке через растризацию по центроидам."""
    if sigma <= 0 or not HAS_SCIPY:
        grid[out_col] = grid[value_col].to_numpy()
        return grid

    cent = grid.geometry.centroid
    xs = np.sort(np.unique(np.round(cent.x.values, 6)))
    ys = np.sort(np.unique(np.round(cent.y.values, 6)))

    x_to_i = {x: i for i, x in enumerate(xs)}
    y_to_j = {y: j for j, y in enumerate(ys)}

    arr = np.full((len(ys), len(xs)), np.nan, dtype=float)

    for idx, row in grid.iterrows():
        c = row.geometry.centroid
        xi = x_to_i[np.round(c.x, 6)]
        yj = y_to_j[np.round(c.y, 6)]
        arr[yj, xi] = row[value_col]

    valid = ~np.isnan(arr)
    filled = np.where(valid, arr, 0.0)
    weight = valid.astype(float)

    smoothed = gaussian_filter(filled, sigma=sigma)
    weights = gaussian_filter(weight, sigma=sigma)
    result = np.where(weights > 0, smoothed / weights, np.nan)

    vals = []
    for idx, row in grid.iterrows():
        c = row.geometry.centroid
        xi = x_to_i[np.round(c.x, 6)]
        yj = y_to_j[np.round(c.y, 6)]
        vals.append(result[yj, xi])

    grid[out_col] = robust_normalize_01(vals, 0.02, 0.98)
    return grid


def recall_at_top_quantile(grid, score_col, positive_cell_ids, top_q=0.90):
    """Доля реальных positive-точек, попавших в верхнюю часть score."""
    if not positive_cell_ids:
        return np.nan
    thr = grid[score_col].quantile(top_q)
    top_cells = set(grid.loc[grid[score_col] >= thr, "cell_id"].tolist())
    pos_set = set(positive_cell_ids)
    return len(pos_set.intersection(top_cells)) / max(len(pos_set), 1)

# %% [markdown]
# ## 3. Загрузка слоёв

# %%
vector_files = []
for ext in ("*.shp", "*.gpkg", "*.geojson", "*.json"):
    vector_files.extend(SHP_DIR.glob(ext))

if not vector_files:
    raise FileNotFoundError(f"В папке не найдены векторные файлы: {SHP_DIR}")

layers = {}
for path in vector_files:
    try:
        name = path.stem
        gdf = read_vector(path)
        if len(gdf) > 0:
            layers[name] = gdf
    except Exception as e:
        print("Не удалось прочитать:", path.name, e)

print("Найденные слои:")
for name, gdf in layers.items():
    print(f"  {name:20s} n={len(gdf):5d} geom={list(gdf.geometry.geom_type.unique())}")
# Out:
# Найденные слои:
#   dayki_buf            n=  151 geom=['Polygon']
#   fasii                n=   15 geom=['Polygon']
#   glub_raz_nw          n=    4 geom=['Polygon']
#   glub_r_nw            n=    2 geom=['Polygon']
#   gr_dol_vp_poly       n=    6 geom=['Polygon']
#   svita_new            n=  101 geom=['Polygon']

# %% [markdown]
# ## 4. Определение факторных слоёв
#
# Если автоматическое сопоставление ошиблось, поправь имена вручную в словаре `aliases`.

# %%
layer_names = list(layers.keys())

aliases = {
    "mask": find_layer_by_keywords(layer_names, ["svita", "свит"]),
    "facies": find_layer_by_keywords(layer_names, ["fasii", "facies", "фаци"]),
    "paleo": find_layer_by_keywords(layer_names, ["gr_dol", "paleo", "дол", "впад"]),
    "struct": find_layer_by_keywords(layer_names, ["kory", "кор"]),
    "magm": find_layer_by_keywords(layer_names, ["dayki", "dyke", "dike", "дай"]),
    "tect_nw": find_layer_by_keywords(layer_names, ["glub_raz", "nw", "сз"]),
    "tect_ne": find_layer_by_keywords(layer_names, ["glub_r", "ne", "св"]),
}

print("Автоматически выбранные слои:")
for k, v in aliases.items():
    print(f"{k:8s}: {v}")

if aliases["mask"] is None:
    raise ValueError("Не найден слой маски. Укажи aliases['mask'] вручную.")
# Out:
# Автоматически выбранные слои:
# mask    : svita_new
# facies  : fasii
# paleo   : gr_dol_vp_poly
# struct  : None
# magm    : dayki_buf
# tect_nw : glub_raz_nw
# tect_ne : glub_raz_nw

# %% [markdown]
# ## 5. Создание сетки 500×500 м и расчёт признаков

# %%
mask = layers[aliases["mask"]].copy()

for key, name in aliases.items():
    if name is not None and layers[name].crs != mask.crs:
        layers[name] = layers[name].to_crs(mask.crs)

grid = make_grid(mask, CELL_SIZE)
print("Количество ячеек сетки:", len(grid))

grid["sed"] = 1

factor_score_cols = []
factor_map = {
    "facies": ("dist_facies", "lyth_score"),
    "paleo": ("dist_paleo", "paleo_score"),
    "struct": ("dist_struct", "struct_score"),
    "magm": ("dist_magm", "magm_score"),
    "tect_nw": ("dist_tect_nw", "tect_nw_score"),
    "tect_ne": ("dist_tect_ne", "tect_ne_score"),
}

for factor_key, (dist_col, score_col) in factor_map.items():
    layer_name = aliases.get(factor_key)
    layer_gdf = layers[layer_name] if layer_name is not None else None
    grid = add_distance_feature(grid, layer_gdf, dist_col, score_col)
    factor_score_cols.append(score_col)

grid["tect_best_score"] = grid[["tect_nw_score", "tect_ne_score"]].max(axis=1)
grid["tect_paleo_score"] = grid["tect_best_score"] * grid["paleo_score"]
grid["facies_struct_score"] = grid["lyth_score"] * grid["struct_score"]
grid["magm_struct_score"] = grid["magm_score"] * grid["struct_score"]

interaction_cols = [
    "tect_best_score",
    "tect_paleo_score",
    "facies_struct_score",
    "magm_struct_score",
]

feature_cols = factor_score_cols + interaction_cols

print("Признаки модели:")
for c in feature_cols:
    print(" ", c)

grid[feature_cols].describe()
# Out:
# Количество ячеек сетки: 15684
# Признаки модели:
#   lyth_score
#   paleo_score
#   struct_score
#   magm_score
#   tect_nw_score
#   tect_ne_score
#   tect_best_score
#   tect_paleo_score
#   facies_struct_score
#   magm_struct_score
#          lyth_score   paleo_score  struct_score    magm_score  tect_nw_score  \
# count  15684.000000  15684.000000           0.0  15684.000000   15684.000000
# mean       0.752237      0.764688           NaN      0.695607       0.847500
# std        0.279637      0.271969           NaN      0.247742       0.231265
# min        0.000000      0.000000           NaN      0.000000       0.000000
# 25%        0.599644      0.628377           NaN      0.537600       0.786701
# 50%        0.859772      0.856221           NaN      0.744914       0.952806
# 75%        0.989670      1.000000           NaN      0.901807       1.000000
# max        1.000000      1.000000           NaN      1.000000       1.000000
#
#        tect_ne_score  tect_best_score  tect_paleo_score  facies_struct_score  \
# count   15684.000000     15684.000000      15684.000000                  0.0
# mean        0.847500         0.847500          0.645927                  NaN
# std         0.231265         0.231265          0.301436                  NaN
# min         0.000000         0.000000          0.000000                  NaN
# 25%         0.786701         0.786701          0.436136                  NaN
# 50%         0.952806         0.952806          0.701014                  NaN
# 75%         1.000000         1.000000          0.916412                  NaN
# max         1.000000         1.000000          1.000000                  NaN
#
#        magm_struct_score
# count                0.0
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %% [markdown]
# ## 6. Расчёт `geo_score`
#
# `geo_score` используется только для формирования псевдометок и слабой стабилизации результата.

# %%
weights = {
    "lyth_score": 1.00,
    "paleo_score": 1.15,
    "struct_score": 1.10,
    "magm_score": 0.85,
    "tect_nw_score": 1.00,
    "tect_ne_score": 1.00,
}

w_sum = sum(weights.values())
geo = np.zeros(len(grid), dtype=float)

for col, w in weights.items():
    geo += grid[col].fillna(0).to_numpy() * (w / w_sum)

coincidence = (
    (grid["lyth_score"] > grid["lyth_score"].quantile(0.70)).astype(float) +
    (grid["paleo_score"] > grid["paleo_score"].quantile(0.70)).astype(float) +
    (grid["struct_score"] > grid["struct_score"].quantile(0.70)).astype(float) +
    (grid["tect_best_score"] > grid["tect_best_score"].quantile(0.70)).astype(float)
) / 4.0

geo = 0.90 * geo + 0.10 * coincidence.to_numpy()
grid["geo_score"] = robust_normalize_01(geo, 0.02, 0.98)

grid["geo_score"].describe()
# Out:
# count    15684.000000
# mean         0.597107
# std          0.245237
# min          0.000000
# 25%          0.459140
# 50%          0.630846
# 75%          0.783704
# max          1.000000
# Name: geo_score, dtype: float64

# %% [markdown]
# ## 7. Сбор реальных точек
#
# `points` — это не файл с таким названием. Это переменная, собранная из точечных слоёв, которые не являются факторными.

# %%
factor_layer_names = list(aliases.values())
points = collect_point_layers(layers, factor_layer_names, mask.crs)

if points is None or len(points) == 0:
    print("Точечные обучающие слои не найдены.")
else:
    print("Количество точек:", len(points))
    display(points["source"].value_counts().to_frame("n"))

    fig, ax = plt.subplots(figsize=(8, 8))
    grid.boundary.plot(ax=ax, linewidth=0.2, color="lightgray")
    points.plot(ax=ax, column="source", markersize=8, legend=True)
    ax.set_title("Точечные слои, используемые как реальные positive-точки")
    ax.set_axis_off()
    plt.show()
# Out:
# Точечные обучающие слои не найдены.

# %% [markdown]
# ## 8. Формирование обучающих меток
#
# Положительный класс:
# - ячейки с реальными точками;
# - верхние значения `geo_score`.
#
# Отрицательный класс:
# - нижние значения `geo_score`.
#
# Средние значения не участвуют в обучении.

# %%
grid["target_ml"] = np.nan
positive_cells = []

if points is not None and len(points) > 0:
    try:
        joined = gpd.sjoin(
            points[["geometry", "source"]],
            grid[["cell_id", "geometry"]],
            how="left",
            predicate="within",
        )
    except Exception:
        joined = gpd.sjoin(
            points[["geometry", "source"]],
            grid[["cell_id", "geometry"]],
            how="left",
            op="within",
        )

    positive_cells = joined["cell_id"].dropna().astype(int).unique().tolist()
    grid.loc[grid["cell_id"].isin(positive_cells), "target_ml"] = 1

pos_thr = grid["geo_score"].quantile(PSEUDO_POS_Q)
neg_thr = grid["geo_score"].quantile(PSEUDO_NEG_Q)

grid.loc[grid["geo_score"] >= pos_thr, "target_ml"] = 1

neg_mask = (grid["geo_score"] <= neg_thr) & (~grid["cell_id"].isin(positive_cells))
grid.loc[neg_mask, "target_ml"] = 0

train = grid.dropna(subset=["target_ml"]).copy()
train["target_ml"] = train["target_ml"].astype(int)

print("Порог positive geo_score:", round(pos_thr, 3))
print("Порог negative geo_score:", round(neg_thr, 3))
print("Всего обучающих ячеек:", len(train))
print(train["target_ml"].value_counts().rename(index={0: "negative", 1: "positive"}))
print("Реальных positive-ячеек:", len(positive_cells))
# Out:
# Порог positive geo_score: 0.932
# Порог negative geo_score: 0.631
# Всего обучающих ячеек: 8783
# target_ml
# negative    7842
# positive     941
# Name: count, dtype: int64
# Реальных positive-ячеек: 0

# %% [markdown]
# ## 9. Обучение Logistic Regression

# %%
X_train = train[feature_cols].fillna(0)
y_train = train["target_ml"].astype(int)

logreg_model = Pipeline([
    ("scaler", StandardScaler()),
    ("logreg", LogisticRegression(
        C=LOGREG_C,
        max_iter=MAX_ITER,
        class_weight="balanced",
        random_state=RANDOM_STATE,
    ))
])

logreg_model.fit(X_train, y_train)

X_all = grid[feature_cols].fillna(0)
grid["lr_score_raw"] = logreg_model.predict_proba(X_all)[:, 1]
grid["lr_score"] = robust_normalize_01(grid["lr_score_raw"], 0.02, 0.98)

grid["ml_score_raw"] = (
    (1 - GEO_STABILIZER) * grid["lr_score"] +
    GEO_STABILIZER * grid["geo_score"]
)
grid["ml_score_raw"] = robust_normalize_01(grid["ml_score_raw"], 0.02, 0.98)

grid = smooth_grid_values(grid, "ml_score_raw", "ml_score", sigma=SMOOTH_SIGMA)

grid["prognoz"] = 1 - grid["ml_score"]

print("Готово. Диапазон ml_score:", grid["ml_score"].min(), grid["ml_score"].max())
# Out:
# Готово. Диапазон ml_score: 0.0 1.0

# %% [markdown]
# ## 10. Главные метрики
#
# Оставлены только ключевые метрики:
# - `ROC_AUC`;
# - `Average_Precision`;
# - `Recall@Top10%`.
#
# Метрики считаются по обучающим меткам, включающим pseudo-labels.

# %%
train_eval = grid.loc[train.index].copy()
y_eval = train_eval["target_ml"].astype(int).to_numpy()
p_eval = train_eval["ml_score"].to_numpy()

roc_auc = roc_auc_score(y_eval, p_eval)
ap = average_precision_score(y_eval, p_eval)
recall_top10 = recall_at_top_quantile(grid, "ml_score", positive_cells, top_q=FINAL_ZONE_Q)

metrics = pd.DataFrame([{
    "Model": "Logistic Regression + pseudo-labels",
    "ROC_AUC": round(float(roc_auc), 3),
    "Average_Precision": round(float(ap), 3),
    "Recall_at_Top10_percent": round(float(recall_top10), 3) if not np.isnan(recall_top10) else np.nan,
    "Positive_mean_prob": round(float(np.mean(p_eval[y_eval == 1])), 3),
    "Negative_mean_prob": round(float(np.mean(p_eval[y_eval == 0])), 3),
}])

display(metrics)
# Out:
#                                  Model  ROC_AUC  Average_Precision  \
# 0  Logistic Regression + pseudo-labels      1.0                1.0
#
#    Recall_at_Top10_percent  Positive_mean_prob  Negative_mean_prob
# 0                      NaN               0.996               0.061

# %% [markdown]
# ## 11. Карта прогноза и сохранение PNG
#
# Синий цвет — более перспективные зоны.
# Жёлтые полигоны — верхние зоны прогноза `gold_zone`, сформированные по верхним 10% `ml_score`.

# %%
zone_thr = grid["ml_score"].quantile(FINAL_ZONE_Q)
grid["gold_zone"] = grid["ml_score"] >= zone_thr

fig, ax = plt.subplots(figsize=(10, 10))

grid.plot(
    column="prognoz",
    ax=ax,
    cmap="bwr",
    legend=False,
    linewidth=0,
)

for key in ["facies", "paleo", "struct", "magm", "tect_nw", "tect_ne"]:
    name = aliases.get(key)
    if name is not None:
        try:
            layers[name].boundary.plot(ax=ax, color="black", linewidth=0.45, alpha=0.65)
        except Exception:
            try:
                layers[name].plot(ax=ax, color="none", edgecolor="black", linewidth=0.45, alpha=0.65)
            except Exception:
                pass

gold = grid[grid["gold_zone"]].copy()
if len(gold) > 0:
    gold.plot(ax=ax, color="gold", edgecolor="black", linewidth=0.5, label="Gold zone")

ax.set_title("Logistic Regression + pseudo-labels forecast", fontsize=14)
ax.set_axis_off()
ax.legend(loc="lower right")

plt.tight_layout()
plt.savefig(PNG_PATH, dpi=300, bbox_inches="tight")
plt.show()

print("PNG сохранён:", PNG_PATH)
# Out:
# PNG сохранён: C:\Users\janfi\OneDrive\Desktop\Прочее\Прогноз\ml_forecast_result\logreg_pseudolabels_forecast.png

# %% [markdown]
# ## 12. Краткая формулировка для отчёта
#
# В качестве основной модели машинного обучения использована логистическая регрессия.
# Из-за ограниченного числа достоверных точек проявлений обучающая выборка была расширена с использованием псевдометок, сформированных по результату геологически обоснованной критериальной оценки `geo_score`.
# Положительный класс сформирован из известных точек и наиболее уверенных перспективных ячеек, отрицательный класс — из наименее перспективных ячеек, а промежуточные значения исключены из обучения.
# Такой подход позволяет сохранить геологическую интерпретируемость результата и одновременно использовать ML как основной инструмент обобщения факторных признаков.
